# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.preprocessing import normalize
# %matplotlib inline

# %%
def load_embeddings(filename):
    
    labels = []
    rows = []
    with open(filename, encoding='utf-8') as infile:
        for i, line in enumerate(infile):
            if i % 100000 == 0:
                print(i)
            items = line.rstrip().split(' ')
            if len(items) == 2:
                continue
            labels.append(items[0])
            
            values = np.array([float(x) for x in items[1:]], 'f')
            # Normalize the values
            ßvalues = normalize(values.reshape(1, -1))
            
            rows.append(values)
        
        arr = np.vstack(rows)
        return pd.DataFrame(arr, index=labels, dtype='f')
    
def show_analogy(embeds, a, b, c, k=5):
    """Compute and print a vector analogy."""
    a, b, c = a.lower(), b.lower(), c.lower()
    va = embeds[embeds.index == a].to_numpy()[0]
    vb = embeds[embeds.index == b].to_numpy()[0]
    vc = embeds[embeds.index == c].to_numpy()[0]
    print("'{a:s}' is to '{b:s}' as '{c:s}' is to ___".format(**locals()))
    
    v = vb - va + vc
    dot_product = np.dot(glove.to_numpy(), v)
    
    other_words_norms = np.linalg.norm(glove.to_numpy(), axis=1)
    this_word_norm = np.linalg.norm(v)

    cos_similarity = np.divide(dot_product, other_words_norms*this_word_norm)

    nns = np.argsort(cos_similarity)[-k:][::-1]
    ds = cos_similarity[nns]
    
    for i, sim in zip(nns, ds):
        target_word = embeds.iloc[i].name
        print("{:.03f} : '{:s}'".format(sim, target_word))
    print("")

# %%
glove = load_embeddings('data/glove.6B.100d.txt')
# Out:
# 0
# 100000
# 200000
# 300000

# %%
show_analogy(glove, "king", "man", "queen")
# Out:
# 'king' is to 'man' as 'queen' is to ___
# 0.804 : 'woman'
# 0.779 : 'man'
# 0.735 : 'girl'
# 0.682 : 'she'
# 0.659 : 'her'

# %%
show_analogy(glove, "man", "shopkeeper", "woman")
# Out:
# 'man' is to 'shopkeeper' as 'woman' is to ___
# 0.801 : 'shopkeeper'
# 0.642 : 'homemaker'
# 0.634 : 'schoolteacher'
# 0.620 : 'housewife'
# 0.597 : 'passerby'

# %%
# Profession words to check
professions = ['businessman','manager','legislator','maid','waiter','waitress','janitor'
               ,'doorman','custodian','gardener','landscaper','stonemason'
               ,'governor','doctor','nurse','attorney','lawyer','dentist','astronaut'
               ,'plumber','barber','hairdresser','cashier','dishwasher','nanny','manicurist'
               ,'bartender','carpenter','programmer','ceo','vp','executive','accountant']

# %%
for profession in professions:
    show_analogy(glove, "american", profession, "mexican")
# Out:
# 'american' is to 'businessman' as 'mexican' is to ___
# 0.749 : 'businessman'
# 0.566 : 'mexican'
# 0.559 : 'banker'
# 0.547 : 'financier'
# 0.546 : 'salinas'
#
# 'american' is to 'manager' as 'mexican' is to ___
# 0.702 : 'manager'
# 0.571 : 'boss'
# 0.547 : 'luis'
# 0.541 : 'roberto'
# 0.522 : 'manuel'
#
# 'american' is to 'legislator' as 'mexican' is to ___
# 0.746 : 'legislator'
# 0.629 : 'lawmaker'
# 0.623 : 'councilor'
# 0.547 : 'pri'
# 0.523 : 'dpp'
#
# 'american' is to 'maid' as 'mexican' is to ___
# 0.789 : 'maid'
# 0.629 : 'housekeeper'
# 0.575 : 'flor'
# 0.535 : 'homolka'
# 0.515 : 'waitress'
#
# 'american' is to 'waiter' as 'mexican' is to ___
# 0.802 : 'waiter'
# 0.668 : 'bartender'
# 0.637 : 'waitress'
# 0.575 : 'busboy'
# 0.568 : 'housekeeper'
#
# 'american' is to 'waitress' as 'mexican' is to ___
# 0.796 : 'waitress'
# 0.698 : 'bartender'
# 0.657 : 'waiter'
# 0.621 : 'housekeeper'
# 0.576 : 'barmaid'
#
# 'american' is to 'janitor' as 'mexican' is to ___
# 0.767 : 'janitor'
# 0.617 : 'bookkeeper'
# 0.612 : 'housekeeper'
# 0.611 : 'bartender'
# 0.580 : 'busboy'
#
# 'american' is to 'doorman' as 'mexican' is to ___
# 0.783 : 'doorman'
# 0.567 : 'waiter'
# 0.539 : 'doormen'
# 0.523 : 'bartender'
# 0.517 : 'receptionist'
#
# 'american' is to 'custodian' as 'mexican' is to ___
# 0.727 : 'custodian'
# 0.506 : 'third-level'
# 0.486 : 'assessor'
# 0.481 : 'mortician'
# 0.479 : 'cornerman'
#
# 'american' is to 'gardener' as 'mexican' is to ___
# 0.690 : 'gardener'
# 0.506 : 'bartender'
# 0.500 : 'plasterer'
# 0.499 : 'housekeeper'
# 0.494 : 'taxidermist'
#
# 'american' is to 'landscaper' as 'mexican' is to ___
# 0.756 : 'landscaper'
# 0.629 : 'cowhand'
# 0.619 : 'bricklayer'
# 0.611 : 'housepainter'
# 0.606 : 'roofer'
#
# 'american' is to 'stonemason' as 'mexican' is to ___
# 0.758 : 'stonemason'
# 0.612 : 'bricklayer'
# 0.589 : 'woodcarver'
# 0.587 : 'cowhand'
# 0.577 : 'plasterer'
#
# 'american' is to 'governor' as 'mexican' is to ___
# 0.786 : 'governor'
# 0.674 : 'gov.'
# 0.585 : 'michoacan'
# 0.582 : 'fortuño'
# 0.565 : 'mexican'
#
# 'american' is to 'doctor' as 'mexican' is to ___
# 0.716 : 'doctor'
# 0.540 : 'mexican'
# 0.522 : 'nurse'
# 0.515 : 'doctors'
# 0.513 : 'dentist'
#
# 'american' is to 'nurse' as 'mexican' is to ___
# 0.716 : 'nurse'
# 0.595 : 'housekeeper'
# 0.548 : 'waitress'
# 0.544 : 'nurses'
# 0.540 : 'dentist'
#
# 'american' is to 'attorney' as 'mexican' is to ___
# 0.738 : 'attorney'
# 0.603 : 'prosecutor'
# 0.595 : 'mexican'
# 0.585 : 'sheriff'
# 0.581 : 'judge'
#
# 'american' is to 'lawyer' as 'mexican' is to ___
# 0.714 : 'lawyer'
# 0.650 : 'attorney'
# 0.580 : 'mexican'
# 0.570 : 'prosecutor'
# 0.568 : 'prosecutors'
#
# 'american' is to 'dentist' as 'mexican' is to ___
# 0.748 : 'dentist'
# 0.607 : 'chiropractor'
# 0.575 : 'pharmacist'
# 0.553 : 'veterinarian'
# 0.550 : 'pediatrician'
#
# 'american' is to 'astronaut' as 'mexican' is to ___
# 0.662 : 'astronaut'
# 0.577 : 'cosmonaut'
# 0.563 : 'gerardo'
# 0.531 : 'pontes'
# 0.518 : 'peruvian'
#
# 'american' is to 'plumber' as 'mexican' is to ___
# 0.785 : 'plumber'
# 0.565 : 'wurzelbacher'
# 0.565 : 'cowhand'
# 0.523 : 'bricklayer'
# 0.520 : 'cabdriver'
#
# 'american' is to 'barber' as 'mexican' is to ___
# 0.697 : 'barber'
# 0.566 : 'ronde'
# 0.510 : 'mora'
# 0.499 : 'alvarado'
# 0.493 : 'rojas'
#
# 'american' is to 'hairdresser' as 'mexican' is to ___
# 0.767 : 'hairdresser'
# 0.628 : 'manicurist'
# 0.626 : 'bartender'
# 0.613 : 'housekeeper'
# 0.590 : 'waitress'
#
# 'american' is to 'cashier' as 'mexican' is to ___
# 0.800 : 'cashier'
# 0.537 : 'bookkeeper'
# 0.529 : 'newsagent'
# 0.527 : 'netto'
# 0.524 : 'waiter'
#
# 'american' is to 'dishwasher' as 'mexican' is to ___
# 0.782 : 'dishwasher'
# 0.520 : 'margaritas'
# 0.518 : 'coffeemaker'
# 0.517 : 'detergent'
# 0.496 : 'tequila'
#
# 'american' is to 'nanny' as 'mexican' is to ___
# 0.765 : 'nanny'
# 0.673 : 'housekeeper'
# 0.521 : 'waitress'
# 0.518 : 'chihuahua'
# 0.518 : 'babysitter'
#
# 'american' is to 'manicurist' as 'mexican' is to ___
# 0.792 : 'manicurist'
# 0.579 : 'storeman'
# 0.564 : 'gold-digger'
# 0.563 : 'loud-mouthed'
# 0.562 : 'floozy'
#
# 'american' is to 'bartender' as 'mexican' is to ___
# 0.799 : 'bartender'
# 0.690 : 'waitress'
# 0.679 : 'waiter'
# 0.578 : 'housekeeper'
# 0.553 : 'barmaid'
#
# 'american' is to 'carpenter' as 'mexican' is to ___
# 0.657 : 'carpenter'
# 0.528 : 'flores'
# 0.524 : 'rivera'
# 0.512 : 'alvarado'
# 0.511 : 'mendoza'
#
# 'american' is to 'programmer' as 'mexican' is to ___
# 0.683 : 'programmer'
# 0.493 : 'camerman'
# 0.478 : 'campos'
# 0.477 : 'programmers'
# 0.465 : 'mário'
#
# 'american' is to 'ceo' as 'mexican' is to ___
# 0.680 : 'ceo'
# 0.567 : 'executive'
# 0.545 : 'marchionne'
# 0.520 : 'cfo'
# 0.512 : 'vice'
#
# 'american' is to 'vp' as 'mexican' is to ___
# 0.734 : 'vp'
# 0.493 : 'atiku'
# 0.444 : 'vice-governor'
# 0.441 : 'boediono'
# 0.439 : 'veep'
#
# 'american' is to 'executive' as 'mexican' is to ___
# 0.672 : 'executive'
# 0.594 : 'ceo'
# 0.582 : 'vice'
# 0.570 : 'chief'
# 0.562 : 'chairman'
#
# 'american' is to 'accountant' as 'mexican' is to ___
# 0.736 : 'accountant'
# 0.605 : 'bookkeeper'
# 0.592 : 'assessor'
# 0.548 : 'housekeeper'
# 0.521 : 'realtor'
